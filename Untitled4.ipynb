# %% [markdown]
# <a href="https://colab.research.google.com/github/tatsatcosmos-ctrl/fictional-octo-broccoli/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML, display

html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<title>AI & Digital Creation Bootcamp for Kids (8–14) | Loppla</title>

<style>
body {
  margin: 0;
  font-family: 'Segoe UI', Arial, sans-serif;
  color: #1f2937;
  background: #ffffff;
  line-height: 1.6;
}
header {
  padding: 80px 20px;
  text-align: center;
  background: linear-gradient(135deg, #eef2ff, #fdf2f8);
}
header h1 {
  font-size: 2.4rem;
  margin-bottom: 15px;
}
header p {
  max-width: 720px;
  margin: auto;
  font-size: 1.1rem;
}
.btn {
  display: inline-block;
  margin: 20px 10px 0;
  padding: 14px 28px;
  background: #6366f1;
  color: white;
  text-decoration: none;
  border-radius: 30px;
  font-weight: 600;
}
section {
  padding: 70px 20px;
  max-width: 1100px;
  margin: auto;
}
section h2 {
  font-size: 2rem;
  margin-bottom: 20px;
  text-align: center;
}
.center {
  text-align: center;
  max-width: 800px;
  margin: auto;
}
.grid {
  display: grid;
  grid-template-columns: repeat(auto-fit, minmax(240px, 1fr));
  gap: 30px;
  margin-top: 40px;
}
.card {
  padding: 25px;
  border-radius: 16px;
  background: #f9fafb;
}
.highlight {
  background: #f0f9ff;
  border-radius: 20px;
  padding: 50px 30px;
}
ul {
  padding-left: 20px;
}
footer {
  background: #111827;
  color: #e5e7eb;
  text-align: center;
  padding: 40px 20px;
}
</style>
</head>

<body>

<header>
  <h1>AI & Digital Creation Bootcamp for Kids (Ages 8–14)</h1>
  <p>A fun, guided 8-week journey where children learn to understand, create,
  and work with technology — not just use it.</p>
  <a href="#" class="btn">Book a Free Demo Class</a>
  <a href="#" class="btn">Enroll Now</a>
</header>

<section>
  <h2>About the Bootcamp</h2>
  <p class="center">
    The AI & Digital Creation Bootcamp is a carefully designed learning experience
    for children aged 8 to 14 years. It builds thinking skills, creativity, and
    digital confidence in a calm, pressure-free environment.
  </p>
</section>

<section class="highlight">
  <h2>Program Highlights</h2>
  <div class="grid">
    <div class="card">👧🧒 Designed for children aged 8–14</div>
    <div class="card">🗓 8 weeks · 1 session per week</div>
    <div class="card">🎮 Hands-on, project-based learning</div>
    <div class="card">👩‍🏫 Small groups with guided mentoring</div>
    <div class="card">🔒 Safe, child-friendly digital tools</div>
    <div class="card">🚫 No exams, no pressure</div>
  </div>
</section>

<section>
  <h2>What Your Child Will Learn</h2>
  <div class="grid">
    <div class="card"><strong>AI Fundamentals</strong><br>Understanding AI in daily life.</div>
    <div class="card"><strong>Game Creation</strong><br>Building simple interactive games.</div>
    <div class="card"><strong>Chatbots</strong><br>Creating AI conversations.</div>
    <div class="card"><strong>App Design</strong><br>Designing basic app interfaces.</div>
    <div class="card"><strong>Websites</strong><br>Creating simple websites.</div>
    <div class="card"><strong>Prompt Engineering</strong><br>Asking smart questions to AI.</div>
  </div>
</section>

<section class="highlight">
  <h2>8-Week Learning Journey</h2>
  <ul class="center">
    <li>Week 1: Understanding AI in Everyday Life</li>
    <li>Week 2: Game Creation & Logic</li>
    <li>Week 3: Chatbot Creation</li>
    <li>Week 4: Smartphone App Design</li>
    <li>Week 5: Digital Movie Making</li>
    <li>Week 6: Website Creation</li>
    <li>Week 7: Chatbot Integration</li>
    <li>Week 8: Responsible AI & Prompting</li>
  </ul>
</section>

<section>
  <h2>Why This Bootcamp Matters</h2>
  <p class="center">
    Children grow up surrounded by technology — but rarely understand how it works.
    This bootcamp helps them think independently, express creatively, and use AI
    responsibly.
    <br><br>
    <strong>Not about engineers. About thinkers.</strong>
  </p>
</section>

<section class="highlight">
  <h2>Ready to Get Started?</h2>
  <p class="center">🎓 Limited seats · 📅 New batches starting soon</p>
  <div class="center">
    <a href="#" class="btn">Book a Free Demo Class</a>
    <a href="#" class="btn">Enroll Now</a>
  </div>
</section>

<footer>
  <p>Helping children explore ideas, create confidently, and grow with technology.</p>
</footer>

</body>
</html>
"""

display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>AI & Digital Creation Bootcamp for Kids (8–14) | Loppla</title>
#
# <style>
# body {
#   margin: 0;
#   font-family: 'Segoe UI', Arial, sans-serif;
#   color: #1f2937;
#   background: #ffffff;
#   line-height: 1.6;
# }
# header {
#   padding: 80px 20px;
#   text-align: center;
#   background: linear-gradient(135deg, #eef2ff, #fdf2f8);
# }
# header h1 {
#   font-size: 2.4rem;
#   margin-bottom: 15px;
# }
# header p {
#   max-width: 720px;
#   margin: auto;
#   font-size: 1.1rem;
# }
# .btn {
#   display: inline-block;
#   margin: 20px 10px 0;
#   padding: 14px 28px;
#   background: #6366f1;
#   color: white;
#   text-decoration: none;
#   border-radius: 30px;
#   font-weight: 600;
# }
# section {
#   padding: 70px 20px;
#   max-width: 1100px;
#   margin: auto;
# }
# section h2 {
#   font-size: 2rem;
#   margin-bottom: 20px;
# ...
